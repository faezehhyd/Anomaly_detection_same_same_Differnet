# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
# set the path
# %cd /content/mydrive/MyDrive/DiffierNetMaster
# Out:
# /content/mydrive/MyDrive/DiffierNetMaster

# %%
from main import run_traning

main_dir = 'MPDD'

class1 = 'bracket_black'
class2 = 'bracket_brown'
class3 = 'bracket_white'
class4 = 'connector'
class5 = 'metal_plate'
class6 = 'tubes'

model1 = class1 + "_model"
model2 = class2 + "_model"
model3 = class3 + "_model"
model4 = class4 + "_model"
model5 = class5 + "_model"
model6 = class6 + "_model"

# %%
meta_epochs = 8
sub_epochs = 4

# %% [markdown]
# > # **Training**

# %%
run_traning(main_dir, class1, model1, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 149MB/s]
# Train epoch 0
# ...

# %%
run_traning(main_dir, class2, model2, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train epoch 0
# Epoch: 0.0 	 train loss: 0.2052
# Epoch: 0.1 	 train loss: -0.6091
# Epoch: 0.2 	 train loss: -0.9589
# Epoch: 0.3 	 train loss: -0.9897
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: -0.9813
# AUROC: 	 last: 0.6146 	 max: 0.6146 	 epoch_max: 0
#
# Train epoch 1
# Epoch: 1.0 	 train loss: -1.1223
# Epoch: 1.1 	 train loss: -1.1889
# ...

# %%
run_traning(main_dir, class3, model3, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train epoch 0
# Epoch: 0.0 	 train loss: 0.3032
# Epoch: 0.1 	 train loss: -0.1911
# Epoch: 0.2 	 train loss: -0.7076
# Epoch: 0.3 	 train loss: -1.0510
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: -1.1225
# AUROC: 	 last: 0.4667 	 max: 0.4667 	 epoch_max: 0
#
# Train epoch 1
# Epoch: 1.0 	 train loss: -1.1679
# Epoch: 1.1 	 train loss: -1.2200
# ...

# %%
run_traning(main_dir, class4, model4, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:02<00:00, 85.8MB/s]
# Train epoch 0
# Epoch: 0.0 	 train loss: 0.6000
# Epoch: 0.1 	 train loss: -0.2634
# Epoch: 0.2 	 train loss: -0.5797
# Epoch: 0.3 	 train loss: -0.6740
#
# ...

# %%
run_traning(main_dir, class5, model5, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train epoch 0
# Epoch: 0.0 	 train loss: 0.6489
# Epoch: 0.1 	 train loss: 0.0450
# Epoch: 0.2 	 train loss: -0.2288
# Epoch: 0.3 	 train loss: -0.5537
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: 15691112.0000
# AUROC: 	 last: 0.9388 	 max: 0.9388 	 epoch_max: 0
#
# Train epoch 1
# Epoch: 1.0 	 train loss: -0.8510
# ...

# %%
run_traning(main_dir, class6, model6, meta_epochs, sub_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train epoch 0
# Epoch: 0.0 	 train loss: 0.3653
# Epoch: 0.1 	 train loss: -0.2734
# Epoch: 0.2 	 train loss: -0.5972
# Epoch: 0.3 	 train loss: -0.7348
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: 1449486336.0000
# AUROC: 	 last: 0.4801 	 max: 0.4801 	 epoch_max: 0
#
# Train epoch 1
# Epoch: 1.0 	 train loss: -0.8106
# ...

# %% [markdown]
# > # **Evaluations**

# %%
from evaluate import evaluate

# %%
evaluate(model1, f'{main_dir}/{class1}/train/good')
# Out:
# image: MPDD/bracket_black/train/good/005.png, score: 1.29
# image: MPDD/bracket_black/train/good/000.png, score: 1.31
# image: MPDD/bracket_black/train/good/007.png, score: 1.18
# image: MPDD/bracket_black/train/good/006.png, score: 1.25
# image: MPDD/bracket_black/train/good/009.png, score: 1.10
# image: MPDD/bracket_black/train/good/002.png, score: 1.14
# image: MPDD/bracket_black/train/good/001.png, score: 1.21
# image: MPDD/bracket_black/train/good/010.png, score: 1.12
# image: MPDD/bracket_black/train/good/008.png, score: 1.19
# image: MPDD/bracket_black/train/good/004.png, score: 1.29
# image: MPDD/bracket_black/train/good/003.png, score: 1.27
# image: MPDD/bracket_black/train/good/046.png, score: 1.25
# image: MPDD/bracket_black/train/good/017.png, score: 1.91
# image: MPDD/bracket_black/train/good/022.png, score: 1.08
# image: MPDD/bracket_black/train/good/039.png, score: 1.35
# image: MPDD/bracket_black/train/good/025.png, score: 1.15
# ...

# %%
evaluate(model2, f'{main_dir}/{class2}/train/good')
# Out:
# image: MPDD/bracket_brown/train/good/003.png, score: 1.04
# image: MPDD/bracket_brown/train/good/012.png, score: 1.13
# image: MPDD/bracket_brown/train/good/010.png, score: 1.15
# image: MPDD/bracket_brown/train/good/005.png, score: 1.03
# image: MPDD/bracket_brown/train/good/000.png, score: 1.22
# image: MPDD/bracket_brown/train/good/006.png, score: 1.03
# image: MPDD/bracket_brown/train/good/013.png, score: 1.11
# image: MPDD/bracket_brown/train/good/007.png, score: 0.93
# image: MPDD/bracket_brown/train/good/004.png, score: 1.03
# image: MPDD/bracket_brown/train/good/015.png, score: 1.02
# image: MPDD/bracket_brown/train/good/001.png, score: 1.04
# image: MPDD/bracket_brown/train/good/008.png, score: 0.96
# image: MPDD/bracket_brown/train/good/017.png, score: 1.08
# image: MPDD/bracket_brown/train/good/011.png, score: 1.04
# image: MPDD/bracket_brown/train/good/009.png, score: 0.97
# image: MPDD/bracket_brown/train/good/002.png, score: 1.07
# ...

# %%
evaluate(model3, f'{main_dir}/{class3}/train/good')
# Out:
# image: MPDD/bracket_white/train/good/015.png, score: 0.86
# image: MPDD/bracket_white/train/good/012.png, score: 0.81
# image: MPDD/bracket_white/train/good/009.png, score: 0.79
# image: MPDD/bracket_white/train/good/008.png, score: 0.84
# image: MPDD/bracket_white/train/good/002.png, score: 1.03
# image: MPDD/bracket_white/train/good/003.png, score: 0.90
# image: MPDD/bracket_white/train/good/011.png, score: 0.83
# image: MPDD/bracket_white/train/good/010.png, score: 0.80
# image: MPDD/bracket_white/train/good/004.png, score: 0.97
# image: MPDD/bracket_white/train/good/001.png, score: 0.96
# image: MPDD/bracket_white/train/good/014.png, score: 0.77
# image: MPDD/bracket_white/train/good/007.png, score: 0.97
# image: MPDD/bracket_white/train/good/000.png, score: 0.88
# image: MPDD/bracket_white/train/good/005.png, score: 0.95
# image: MPDD/bracket_white/train/good/013.png, score: 0.86
# image: MPDD/bracket_white/train/good/006.png, score: 0.88
# ...

# %%
evaluate(model4, f'{main_dir}/{class4}/train/good')

# %%
evaluate(model5, f'{main_dir}/{class5}/train/good')

# %%
evaluate(model6, f'{main_dir}/{class6}/train/good')
